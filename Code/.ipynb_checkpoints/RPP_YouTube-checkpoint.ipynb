# %%
#!pip install --upgrade google-api-python-client
#!pip install pysentimiento
#!pip install --upgrade pandas
#!pip install --upgrade matplotlib

# %%
import os
import requests
import re
import json
import time # to call the .sleep() method to include a pause that respects potential respect API limits
import pandas as pd
import matplotlib.pyplot as plt

from googleapiclient.discovery import build
from youtube_api import YouTubeDataAPI
from youtube_api import parsers as P
from datetime import datetime

YT_KEY = os.environ.get('YOUTUBE_API_KEY') # Key is saved in ~/.zshrc
api_key = YT_KEY
yt = YouTubeDataAPI(YT_KEY)

# %%
from requests.exceptions import HTTPError, ReadTimeout

# %%
from datetime import datetime

class DateTimeEncoder(json.JSONEncoder):
    """Custom encoder for datetime objects."""
    def default(self, obj):
        if isinstance(obj, datetime):
            return obj.isoformat()  # Convert datetime to ISO format string
        # Let the base class default method raise the TypeError
        return super().default(obj)

# %%
directory = '../data/rpp_sinopharm'

# %%
'''searches = yt.search(q='alexandria ocasio-cortez',
                     max_results=5)
print(searches[0])'''

# %%
'''
vid_mtdata = yt.get_video_metadata(video_id="N8TCILfoxqk", parser=P.parse_video_metadata, part=['statistics','snippet'])
print(vid_mtdata)
'''
# Out:
# {'video_id': 'N8TCILfoxqk', 'channel_title': 'PBO', 'channel_id': 'UCgR0st4ZLABi-LQcWNu3wnQ', 'video_publish_date': 1615074127.0, 'video_title': 'Beto Ortiz reveló que vacuna contra COVID de Sinopharm que Perú compró tiene bajo nivel de eficacia', 'video_description': '👉 BETO A SABER: RESULTADO DEL ESTUDIO CLÍNICO \n\n🔴 Beto Ortiz reveló que la vacuna contra el coronavirus de #Sinopharm que Perú compró tiene bajo nivel de eficacia\n🔴 #ENTREVISTA Dr. Ernesto Bustamante\n\n📻 PBO Radio 91.9 FM ¡LA RADIO CON FE!\n🌍 pboradio.com\n🔴 https://youtu.be/N8TCILfoxqk\n#hashtag\nButters #butters #URGENTE #LOÚLTIMO Vizcarra #COVID-19 Peru #Lima Minsa Sagasti Willax Sinopharm Chinos Ugarte Cayetano Pfizer\n\n\nPBO es el primer canal multi-plataforma de Perú. Fundado en el 2016 por Phillip Butters, PBO te trae lo último en información, comentarios políticos, tecnología, salud, deporte y entretenimiento.\n\nSíguenos en Facebook: http://www.facebook.com/pbodigital\n\nSíguenos en Twitter: http://www.tw
# ...

# %%
'''
vid_comments = yt.get_video_comments(video_id="N8TCILfoxqk", parser=P.parse_comment_metadata, get_replies=True,
                                     max_results=None, next_page_token=False,
                                     part=['snippet'])
'''
# Out:
# '\nvid_comments = yt.get_video_comments(video_id="N8TCILfoxqk", parser=P.parse_comment_metadata, get_replies=True,\n                                     max_results=None, next_page_token=False,\n                                     part=[\'snippet\'])\n'

# %%
''' 
# Method get playlist from channel

ch_playlists = yt.get_playlists(channel_id, next_page_token=False, parser=P.parse_playlist_metadata, part=['id', 'snippet', 'contentDetails'])

'''
# Out:
# " \nMethod to get playlist from channel\nch_playlists = yt.get_playlists(channel_id, next_page_token=False, parser=P.parse_playlist_metadata, part=['id', 'snippet', 'contentDetails'])"

# %%
'''
df_prsd_comments = pd.DataFrame(vid_comments)
df_prsd_comments.head(5)
'''
# Out:
# '\ndf_prsd_comments = pd.DataFrame(vid_comments)\ndf_prsd_comments.head(5)\n'

# %%
''' Function to get the ID of a YouTube channel using the channel's display_name'''

def find_channel_id_by_display_name(display_name, api_key):
    # Define the endpoint and parameters for the request
    search_url = 'https://www.googleapis.com/youtube/v3/search'
    params = {
        'part': 'snippet',
        'q': display_name,
        'type': 'channel',
        'key': api_key
    }
    
    # Make the GET request
    response = requests.get(search_url, params=params)
    
    # Check if the request was successful
    if response.status_code == 200:
        # Parse the response
        search_results = response.json()
        
        # Loop through the search results and find the matching channel
        for item in search_results.get('items', []):
            # Check if the snippet's channel title closely matches the search query (display name)
            if item['snippet']['channelTitle'].lower() == display_name.lower():
                return item['snippet']['channelId']
        
        # If no exact match is found, return a message
        return "No exact match found for the display name."
    else:
        # If the request was not successful, return an error message with the status code
        return f"Failed to retrieve data: HTTP Status Code {response.status_code}"

# %%
''' Function to get the ID of a YouTube channel using the Channel's username'''

def get_channel_id(channel_username, api_key):
    try:
        # Make a GET request to the YouTube Data API's channels.list method
        response = requests.get(
            'https://www.googleapis.com/youtube/v3/channels',
            params={
                'part': 'id',
                'forUsername': channel_username,
                'key': api_key
            }
        )
        
        # Check if the request was successful
        if response.status_code == 200: # status code of 200 indicates successful request (API endpoint was reached without any errors)
            response_json = response.json() # parse the JSON content returned by the API into a Python dictionary
            items = response_json.get('items', []) # retrieves 'items' list from JSON object
            
            if items:
                # Assuming the first item is the correct channel
                channel_id = items[0]['id']
                return channel_id
            else:
                return "No channel found for the given username."
        else:
            return "Failed to retrieve data: HTTP Status Code {}".format(response.status_code)
    except Exception as e:
        # Handle potential exceptions, such as a network error
        return "An error occurred: {}".format(e)

# %%
# Create variables for channel user name or display name

channel_username = 'RPPNoticias' # List of channel usernames
display_name = 'RPPNoticias'  # The display name of the channel I am searching for

# %%
#RPP Noticias channel ID
channel_id = "UC5j8-2FT0ZMMBkmK72R4aeA"

# %%
# Search for channel ID using the functions and variables defined 

# Call get_channel_id for each username
channel_id = get_channel_id(channel_username, api_key)
if channel_id == "No channel found for the given username.":
    channel_id = find_channel_id_by_display_name(channel_username, api_key) # Using the find_channel_id_by_display_name
    
    # Store the result in the dictionary
    channel_ids[channel_username] = channel_id

#Debug: Print resulting dictionary
print(channel_id)

'''I NEED TO STORE THIS INFORMATION INTO A FILE THAT I CAN UPDATE WHEN I GET A NEW CHANNEL ID'''
# Out:
# UC5j8-2FT0ZMMBkmK72R4aeA
# 'I NEED TO STORE THIS INFORMATION INTO A FILE THAT I CAN UPDATE WHEN I GET A NEW CHANNEL ID'

# %%
'''Simple video search by channel, keywords, and extreme dates'''

# Build the YouTube service object
youtube = build('youtube', 'v3', developerKey=api_key)

# Define date range in RFC 3339 format
publishedAfter = datetime(2021, 1, 1).isoformat() + 'Z'
publishedBefore = datetime(2022, 6, 30).isoformat() + 'Z'
regionCode = "PE"
relevanceLanguage = "es"

# Execute the search request
search_response = youtube.search().list(
    part='snippet',
    type='video',
    channelId="UC5j8-2FT0ZMMBkmK72R4aeA",
    publishedAfter=publishedAfter,
    publishedBefore=publishedBefore,
    regionCode = "PE",
    maxResults=50,  # Adjust as needed, up to 50
    q="sinopharm|Sinopharm|ernesto bustamante|Ernesto Bustamante"
)
response = search_response.execute()
print(response)
# Out:
# {'kind': 'youtube#searchListResponse', 'etag': '5wfGH14pkuerBwd2GJ0pFjVs7eM', 'nextPageToken': 'CDIQAA', 'regionCode': 'PE', 'pageInfo': {'totalResults': 224, 'resultsPerPage': 50}, 'items': [{'kind': 'youtube#searchResult', 'etag': 'nC8DYcuOS_04-D6j_nsZl36OE0o', 'id': {'kind': 'youtube#video', 'videoId': 'zcFgzY8rsyU'}, 'snippet': {'publishedAt': '2021-08-05T00:32:17Z', 'channelId': 'UC5j8-2FT0ZMMBkmK72R4aeA', 'title': 'Vacuna de Sinopharm: Colegio de Biólogos rechaza declaraciones del congresista Ernesto Bustamante', 'description': 'El Colegio de Biólogos del Perú informó que las declaraciones del congresista de Fuerza Popular, Ernesto Bustamante, sobre la ...', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zcFgzY8rsyU/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/zcFgzY8rsyU/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/zcFgzY8rsyU/hqdefault.jpg', 'width': 480, 'height': 360}}, 'channelTitle
# ...

# %%
# Save search result in json file
search_result_file = "rpp_sinopharm_videos2.json"
vid_file_path = os.path.join(directory, search_result_file)

with open(vid_file_path, 'w') as file:
    json.dump(response, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {vid_file_path}")
# Out:
# Data saved to data/rpp_sinopharm/rpp_sinopharm_videos2.json

# %%
'''
Get the playlists for RPP Noticias channel
'''

# Build the YouTube service object
youtube = build('youtube', 'v3', developerKey=api_key)

# Initialize variables for pagination
page_token = None
all_results = []

while True:
    # Make the request to the YouTube API
    request = youtube.playlists().list(
        part="contentDetails,id,snippet",
        channelId="UC5j8-2FT0ZMMBkmK72R4aeA",
        maxResults=50,  # The maximum allowed value
        pageToken=page_token  # Use the pageToken for pagination
    )

    response = request.execute()
    
    # Add the response items to the results list
    all_results.extend(response.get('items', []))
    
    # Check if there is a next page token
    page_token = response.get('nextPageToken')
    if not page_token:
        break

print(all_results)

# Save the data
rpp_playlists = "rpp_playlists.json"
playlist_file_path = os.path.join(directory, rpp_playlists)

with open(playlist_file_path, 'w') as file:
    json.dump(all_results, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {playlist_file_path}")
# Out:
# [{'kind': 'youtube#playlist', 'etag': 'RXV1hH9VN3cIs8xz0erIgd7FyEU', 'id': 'PLKB9XoDgSNZyiyYBi97-so1OyOqdpnzg8', 'snippet': {'publishedAt': '2024-05-09T20:43:12Z', 'channelId': 'UC5j8-2FT0ZMMBkmK72R4aeA', 'title': 'FÚTBOL COMO CANCHA', 'description': '', 'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/mvfDyZtwXWs/default.jpg', 'width': 120, 'height': 90}, 'medium': {'url': 'https://i.ytimg.com/vi/mvfDyZtwXWs/mqdefault.jpg', 'width': 320, 'height': 180}, 'high': {'url': 'https://i.ytimg.com/vi/mvfDyZtwXWs/hqdefault.jpg', 'width': 480, 'height': 360}, 'standard': {'url': 'https://i.ytimg.com/vi/mvfDyZtwXWs/sddefault.jpg', 'width': 640, 'height': 480}, 'maxres': {'url': 'https://i.ytimg.com/vi/mvfDyZtwXWs/maxresdefault.jpg', 'width': 1280, 'height': 720}}, 'channelTitle': 'RPP Noticias', 'localized': {'title': 'FÚTBOL COMO CANCHA', 'description': ''}}, 'contentDetails': {'itemCount': 1}}, {'kind': 'youtube#playlist', 'etag': 'G9E0r4gn-uwst3_a3MPMiRHK280', 'id': 'PLKB9XoDgSNZwK
# ...

# %%
'''
Create Dataframe with details from playlists metadata
'''

rpp_pl = [] 

# Open the playlists file
filename = 'data/rpp_sinopharm/rpp_playlists.json'

# Load existing data if the file exists
if os.path.exists(filename):
    with open(filename, 'r') as file:
        playlists_rpp = json.load(file)
else:
    raise FileNotFoundError("The file: '" + filename + "' doesn't exist. Check its name or path.")


for playlists in playlists_rpp:
    playlist_data = playlists["snippet"]
    new_playlist_dict = {}
    #print(f"Playlist: {playlist_data['title']}")
    
    try:
        new_playlist_dict['channelId'] = playlist_data['channelId']
        new_playlist_dict['channelTitle'] = playlist_data['channelTitle']
        new_playlist_dict['playlistId'] = playlists["id"]
        new_playlist_dict['title'] = playlist_data['title']
        new_playlist_dict["publishedAt"] = playlist_data["publishedAt"]
        new_playlist_dict['description'] = playlist_data['description']
        new_playlist_dict['itemCount'] = playlists['contentDetails']['itemCount']
        
        rpp_pl.append(new_playlist_dict)

    except Exception as e:
        print(f"Error processing video: {e}")

#len(rpp_pl)

playlists_df = pd.DataFrame(rpp_pl)
#playlists_df.head(5)
playlists_df.to_csv("data/rpp_sinopharm/rpp_playlists.csv")

# %%
'''
Get videos from playlist file and save them into new json file

1. Initiate list (playlist_vids) to store videos fetched from the playlists. 
   The videos from each playlist will be stored in an independent 
   list inside the initiated list (playlist_vids)
2. open playlist csv file
3. for loop to iterate in the playlists dictionary
4. get playlist_Id
5. yt function to get videos (and their metadata) from playlist
6. store the data in a json file
'''

playlist_vids = []

# Open the playlists file
playlists_file = pd.read_csv("data/rpp_sinopharm/rpp_playlists_filtered.csv")


for id in playlists_file['playlistId']:
    #print(id)    
    # Call the function to get videos from this playlist ID
    videos = yt.get_videos_from_playlist_id(playlist_id=id, 
                                                    next_page_token=None, 
                                                    parser=P.parse_video_url, 
                                                    part=['snippet'], 
                                                    max_results=200000)
    playlist_vids.append(videos)   
    time.sleep(20)  # Pause to respect API limits

f = 'data/rpp_sinopharm/rpp_videos_unfiltered.json'

with open(f, 'w') as file:
    json.dump(playlist_vids, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {f}")
print(f"Number of videos fetched: {len(playlist_vids)}")
# Out:
# Data saved to data/rpp_sinopharm/rpp_videos_unfiltered.json
# Number of videos fetched: 71

# %%
'''
Get video IDs from file, filtering by date
'''

# assign directory

rpp_unfiltered_vids = "rpp_videos_unfiltered.json"
f_path = os.path.join(rpp_directory, rpp_unfiltered_vids)  # Get the full path to the file

if os.path.isfile(f_path):
    with open(f_path, 'r') as file:  # Open the file using its full path
        vids = json.load(file)
    
# Define date range in RFC 3339 format
# start_date = datetime(2020, 10, 1).timestamp() #1601535600
# end_date = datetime(2021, 8, 31).timestamp()
# start_date = datetime(2021, 9, 1).timestamp()
# end_date = datetime(2022, 3, 31).timestamp()
start_date = datetime(2022, 4, 1).timestamp()
end_date = datetime(2022, 9, 30).timestamp()
    
# Filter videos within the date range and collect their video_ids
videos_ids = []
for playlist in vids:
    for video in playlist:
        publish_date = video['publish_date']
        if start_date <= publish_date <= end_date:
            videos_ids.append(video['video_id'])

print(f"Total videos to retrieve: {len(videos_ids)}")
#print(videos_ids)
# Out:
# Total videos to retrieve: 6088

# %%
# Process each video ID as before
# Initialize matched_metadata outside the loop
retrieved_videos = []

for video_id in videos_ids:
    try:
        print(f"Retrieving metadata for video_ID: {video_id}")
        vid_metadata = yt.get_video_metadata(video_id=video_id, 
                                             parser=P.parse_video_metadata, 
                                             part=['statistics', 'snippet'])
        retrieved_videos.append(vid_metadata)
    except (HTTPError, ReadTimeout) as e:
        print(f"Failed to retrieve metadata for video_ID: {video_id} due to error: {e}")
        continue  # Skip to the next video ID
    time.sleep(3)  # Delay between requests
# Out:
# Retrieving metadata for video_ID: YiMM8kkDDDM
# Retrieving metadata for video_ID: YLN9ZMfUEWI
# Retrieving metadata for video_ID: biToIHLxacU
# Retrieving metadata for video_ID: OHQPu7_TeDU
# Retrieving metadata for video_ID: X2HURf6LkYg
# Retrieving metadata for video_ID: EfBWBvCTHbQ
# Retrieving metadata for video_ID: kzR3drds1pI
# Retrieving metadata for video_ID: WPtaQqzdBjE
# Retrieving metadata for video_ID: 6rC8lcyXeak
# Retrieving metadata for video_ID: 7gXJcWJHwoQ
# Retrieving metadata for video_ID: 4Ld4N81y1-I
# Retrieving metadata for video_ID: Li3uQzzBZLc
# Retrieving metadata for video_ID: xrr88MaE2Ds
# Retrieving metadata for video_ID: y7QTkwwcJeg
# Retrieving metadata for video_ID: XifR6uQApm8
# Retrieving metadata for video_ID: 50f0Gob8tG8
# Retrieving metadata for video_ID: VqOBpZVTMDk
# Retrieving metadata for video_ID: fCAArPXhKtI
# Retrieving metadata for video_ID: VPpNTERo9bo
# Retrieving metadata for video_ID: 7AK-fjQVDrE
# ...

# %%
'''
Continue fetching video metadata from the point (video ID) where the system cut me off
'''

stopped_at = "SnNPCu2ZreA"

# Find the index to start from
start_index = videos_ids.index(stopped_at)
start_index = start_index + 1 

retrieved_videos = []

# Iterate starting from the specified index
for video_id in videos_ids[start_index:]:
    try:
        print(f"Retrieving metadata for video_ID: {video_id}")
        vid_metadata = yt.get_video_metadata(video_id=video_id, 
                                             parser=P.parse_video_metadata, 
                                             part=['statistics', 'snippet'])
        retrieved_videos.append(vid_metadata)
    except HTTPError as e:
        print(f"Failed to retrieve metadata for video_ID: {video_id} due to HTTPError: {e}")
        continue  # Skip to the next video ID
    time.sleep(3)  # Delay between requests
# Out:
# Retrieving metadata for video_ID: -Tqg_Sni3yc
# Retrieving metadata for video_ID: Qw-yQ-QSOE8
# Retrieving metadata for video_ID: jIwDEx5fMGY
# Retrieving metadata for video_ID: HrCC9W98nSc
# Retrieving metadata for video_ID: 0jAxRAq-RmA
# Retrieving metadata for video_ID: t_E3O-km0J4
# Retrieving metadata for video_ID: _jPAwpwGwCw
# Retrieving metadata for video_ID: VU-foTCrLUM
# Retrieving metadata for video_ID: IcnmbOsWczY
# Retrieving metadata for video_ID: Pg-7uJKc0uI
# Retrieving metadata for video_ID: 9ZuwblyXvNs
# Retrieving metadata for video_ID: 8vI8qL0HJ1M
# Retrieving metadata for video_ID: lB-bxZaGrag
# Retrieving metadata for video_ID: ofgOfNyiyC4
# Retrieving metadata for video_ID: R2nRyFG4U68
# Retrieving metadata for video_ID: 52e0ZNPuA5w
# Retrieving metadata for video_ID: Ve6yf1LrKBs
# Retrieving metadata for video_ID: UeMNrz3jMF4
# Retrieving metadata for video_ID: T-XCM5p7GpU
# Retrieving metadata for video_ID: ZPKn3Lp1vkg
# ...

# %%
# Choose an appropriate filename for saving the data
video_dets_file = "rpp_videos_date_filter7.json"
vid_file_path = os.path.join(directory, video_dets_file)

with open(vid_file_path, 'w') as file:
    json.dump(retrieved_videos, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {vid_file_path}")
print(f"Number of videos saved: {len(retrieved_videos)}")
# Out:
# Data saved to data/rpp_sinopharm/rpp_videos_date_filter7.json
# Number of videos saved: 3728

# %%
dir_path = "data/rpp_sinopharm/rpp_date_filtered_videos"

# Define the search terms
terms = ['sinopharm', 'vacuna', 'vacunas', 'efectividad', 'efectiva', 'efectivas', 'eficaz', 'eficacia', 'eficaces', 'eficiencia', 
         'minsa', 'digemind', 'bustamante']

# Compile a regex pattern for case-insensitive search of these terms
pattern = re.compile(r'\b(?:' + '|'.join(re.escape(term) for term in terms) + r')\b', re.IGNORECASE)

matching_videos_count = 0
filtrd_lst = []
seen_video_ids = set()

# Iterate over all files in the directory
for filename in os.listdir(dir_path):
    filepath = os.path.join(dir_path, filename)
    with open(filepath, 'r', encoding='utf-8') as file:
        videos = json.load(file)
        for video in videos:
            try:
                if type(video) == dict and (pattern.search(video['video_title']) or pattern.search(video['video_description'])):
                    video_id = video.get('video_id')
                    if video_id and video_id not in seen_video_ids:
                        seen_video_ids.add(video_id)
                        filtrd_lst.append(video)
                        #print("Appending", video['video_title'], "to filtrd_lst")
                    matching_videos_count += 1
            except Exception as e:
                print("Error processing video:", video)
                print(e)

print("Total number of videos processed:", len(filtrd_lst))
print("Total matching videos count:", matching_videos_count)

extracted_videos = "rpp_sinoph_efectividad.json"
vid_file_path = os.path.join(directory, extracted_videos)

with open(vid_file_path, 'w') as file:
    json.dump(filtrd_lst, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {vid_file_path}")
print(f"Number of videos saved: {len(filtrd_lst)}")
# Out:
# Total number of videos processed: 1033
# Total matching videos count: 1901
# Data saved to data/rpp_sinopharm/rpp_sinoph_efectividad.json
# Number of videos saved: 1033

# %%
'''Another method to do the same'''

'''
dir_path = "data/rpp_sinopharm/rpp_date_filtered_videos"

# Define the search terms
terms = ['sinopharm', 'vacuna', 'vacunas', 'efectividad', 'eficacia', 'eficiencia', 
         'minsa', 'digemind', 'bustamante']

# Compile a regex pattern for case-insensitive search of these terms
pattern = re.compile(r'\b(?:' + '|'.join(re.escape(term) for term in terms) + r')\b', re.IGNORECASE)

matching_videos_count = 0
videos_list = []

# Iterate over all files in the directory
for filename in os.listdir(dir_path):
    filepath = os.path.join(dir_path, filename)
    with open(filepath, 'r', encoding='utf-8') as file:
        videos = json.load(file)
        for video in videos:
            try:
                if type(video) == dict and (pattern.search(video['video_title']) or pattern.search(video['video_description'])):
                    videos_list.append(video)
                    matching_videos_count += 1
            except Exception as e:
                print("Error processing video:", video)
                print(e)

# Load into a DataFrame and drop duplicates based on 'video_id'
df = pd.DataFrame(videos_list)
df.drop_duplicates(subset='video_id', inplace=True)

print("Total number of unique videos processed:", len(df))
print("Total matching videos count:", matching_videos_count)

# Convert DataFrame back to list if needed
filtrd_lst = df.to_dict(orient='records')
'''
# Out:
# Total number of unique videos processed: 954
# Total matching videos count: 1795

# %%
df_rpp_sinoph = pd.DataFrame(filtrd_lst)
df_rpp_sinoph
# Out:
#         video_id channel_title                channel_id  video_publish_date  \
# 0    2Zcik-BInj4  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.627427e+09
# 1    N3vs5lSMQHg  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.626428e+09
# 2    7JEQeqYc9-U  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.622849e+09
# 3    alc2qHTdUgo  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.622666e+09
# 4    OkYlXt8NXDs  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.619695e+09
# ..           ...           ...                       ...                 ...
# 949  TlVQCmigtfk  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.631043e+09
# 950  Vbtad9uZdfA  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.630698e+09
# 951  QY099ZbvaFg  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.648603e+09
# 952  SOjdo5deJpA  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.648512e+09
# 953  7PJrVQM2tZk  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.647909e+09
#
# ...

# %%
#df_willax_sinoph.dtypes
df_rpp_sinoph.info
# Out:
# <bound method DataFrame.info of         video_id channel_title                channel_id  video_publish_date  \
# 0    2Zcik-BInj4  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.627427e+09
# 1    N3vs5lSMQHg  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.626428e+09
# 2    7JEQeqYc9-U  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.622849e+09
# 3    alc2qHTdUgo  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.622666e+09
# 4    OkYlXt8NXDs  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.619695e+09
# ..           ...           ...                       ...                 ...
# 949  TlVQCmigtfk  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.631043e+09
# 950  Vbtad9uZdfA  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.630698e+09
# 951  QY099ZbvaFg  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.648603e+09
# 952  SOjdo5deJpA  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.648512e+09
# 953  7PJrVQM2tZk  RPP Noticias  UC5j8-2FT0ZMMBkmK72R4aeA        1.647909e+09
#
# ...

# %%
# Define the search keywords correctly
keywords = ['sinopharm', 'efectividad', 'efectiva', 'efectivas', 'eficaz', 'eficacia', 'eficaces', 'eficiencia', 
         'minsa', 'digemind']

# Compile a regex pattern for case-insensitive search of these keywords
pattern = re.compile(r'\b(?:' + '|'.join(re.escape(keyword) for keyword in keywords) + r')\b', re.IGNORECASE)


fil_video_lst = []

   
# Search in both the video title and description
for video in filtrd_lst:

    try:
        #if pattern_to_remove.search(video_data['channelTitle']) or pattern_to_remove.search(video_data['description']):
            #continue
        if pattern.search(video['video_title']) or pattern.search(video['video_description']):
                  
            fil_video_lst.append(video)

    except Exception as e:
        print(f"Error processing video: {e}")

extracted_vids = "rpp_sinoph_efectividad2.json"
vid_file_path = os.path.join(directory, extracted_vids)

with open(vid_file_path, 'w') as file:
    json.dump(fil_video_lst, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {vid_file_path}")
print(f"Number of videos saved: {len(fil_video_lst)}")
# Out:
# Data saved to data/rpp_sinopharm/rpp_sinoph_efectividad2.json
# Number of videos saved: 499

# %%
filename = "sinoph_efectiv_rpp_revised.csv"
filepath = os.path.join(directory, filename)


video_list = []

try:
    df = pd.read_csv(filepath)
    #print(df.head())  # Display the first 5 rows of the dataframe
except FileNotFoundError as e:
    print(f"File not found: {e}")
except pd.errors.ParserError as e:
    print(f"Error parsing CSV file: {e}")

video_ids = df["video_id"]

# Dictionary to store the comments for each video
video_comments_dict = {}

for video_id in video_ids[100:]: 
    try:
        vid_comments = yt.get_video_comments(video_id=video_id, parser=P.parse_comment_metadata, get_replies=True,
                                             max_results=None, next_page_token=False,
                                             part=['snippet'])
        
        # Assuming yt.get_video_comments raises an exception on failure and does not return a response object
        # Store the comments in a dictionary using the video_id as the key
        video_comments_dict[video_id] = vid_comments
        
    except Exception as e:
        # Handle potential exceptions, such as a network error or API error
        print("An error occurred for video ID {}: {}".format(video_id, e))
        
    time.sleep(5)  # Delay of 5 seconds between requests'''

# %%
video_comments_dict
# Out:
# {'CuF-2taa43k': [{'video_id': 'CuF-2taa43k',
#    'commenter_channel_url': 'http://www.youtube.com/@isabelmarujarodrigueztirad4663',
#    'commenter_channel_id': 'UCt-AO0xnOgbthSjr2rOsAjg',
#    'commenter_channel_display_name': '@isabelmarujarodrigueztirad4663',
#    'comment_id': 'UgxQndweI8gGU2Sbvwx4AaABAg',
#    'comment_like_count': 0,
#    'comment_publish_date': 1631284144.0,
#    'text': 'JAIME CHINCHA ESTA CIRCULANDO EN LAS REDES LA LISTAS DE LAS EMPRESAS QUE LE DEBEN MILLONES DE SOLES,EN IMPUESTOS A LA SUNAT ,DIGO YO TU COMO ERES UN PERIODISTA CON CREDIBILIDAD NO TE VAS A PRONUNCIAR YA QUE ESE DINERO EN ESTE TIEMPO NOS ACE FALTA.',
#    'commenter_rating': 'none',
#    'comment_parent_id': None,
#    'collection_date': datetime.datetime(2024, 5, 20, 22, 53, 47, 325452),
#    'reply_count': 0},
#   {'video_id': 'CuF-2taa43k',
#    'commenter_channel_url': 'http://www.youtube.com/@marcodevinatea9339',
#    'commenter_channel_id': 'UCh5fTkzNB47P2_CkAN10lnA',
# ...

# %%
comments_file = "rpp_sinoph_comments3.json"
file_path = os.path.join(directory, comments_file)

with open(file_path, 'w') as file:
    json.dump(video_comments_dict, file, cls=DateTimeEncoder, indent=4)

print(f"Data saved to {file_path}")
# Out:
# Data saved to ../data/rpp_sinopharm/rpp_sinoph_comments3.json

# %%
'''# Convert UNIX timestamp to human-readable date (the unit='s' specifies that the timestamp is in seconds)
df_willax_sinoph["video_publish_date"] = pd.to_datetime(df_willax_sinoph["video_publish_date"], unit='s', origin='unix')
df_willax_sinoph["video_publish_date"] = df_willax_sinoph["video_publish_date"].dt.date
df_willax_sinoph = df_willax_sinoph.sort_values(by="video_publish_date", ascending=True)
#print(df_willax_sinoph)'''
# Out:
#         video_id      channel_title                channel_id  \
# 50   yPgMc7mA6yw  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 100  jcSbPDRAvEc  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 84   t5AsmlQtnpE  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 99   Jrfc01d6rKY  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 98   duE2l__1D8M  Willax Televisión  UCort3mldTtMErPqprSlSfng
# ..           ...                ...                       ...
# 51   -2uGfZLjFtY  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 3    HOBbYwav4CM  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 85   ER8T0SRG-vQ  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 2    wWd-rfjuJbo  Willax Televisión  UCort3mldTtMErPqprSlSfng
# 1    pcyhr7yaUxA                PBO  UCgR0st4ZLABi-LQcWNu3wnQ
#
#     video_publish_date                                        video_title  \
# 50          2020-10-07  Ernesto Bustamante anuncia participación en li...
# ...

# %%
'''willax_sinoph_sub = df_willax_sinoph[['video_publish_date', 'video_id', 'video_title', 
                                      'video_description', 'video_view_count', 'video_comment_count', 
                                      'channel_title', 'channel_id']].rename(columns = {
        'video_publish_date': 'publish_date',
        'video_title': 'title', 
        'video_description': 'description',
        'video_view_count': 'views', 
        'video_comment_count': 'comment_count',
        'channel_title': 'channel' 
    }
)
willax_sinoph_sub'''
# Out:
#     publish_date     video_id  \
# 50    2020-10-07  yPgMc7mA6yw
# 100   2020-10-29  jcSbPDRAvEc
# 84    2020-11-07  t5AsmlQtnpE
# 99    2020-11-17  Jrfc01d6rKY
# 98    2020-12-03  duE2l__1D8M
# ..           ...          ...
# 51    2021-06-29  -2uGfZLjFtY
# 3     2021-06-29  HOBbYwav4CM
# 85    2021-07-13  ER8T0SRG-vQ
# 2     2021-12-15  wWd-rfjuJbo
# 1     2021-12-17  pcyhr7yaUxA
#
#                                                  title  \
# 50   Ernesto Bustamante anuncia participación en li...
# 100  Combutters: Segunda ola llegó a europa - OCT 2...
# 84   Ernesto Bustamante: "La propaganda de Vizcarra...
# 99   Combutters: Vacuna estadounidense pasa a la de...
# 98   Combutters: VACUNA: HAY LUZ AL FINAL DEL TÚNEL...
# ..                                                 ...
# 51   Beto a Saber - JUN 28 - 1/3 - VACADO Y TRES VE...
# 3    Milagros Leiva Entrevista - JUN 28 - 2/3 - VIZ...
# 85   Combutters - JUL 12 - 4/4 | MÉDICOS PIDEN VACU...
# ...

# %%
'''wil_sino_mar_sep_21 = willax_sinoph_sub[
    (willax_sinoph_sub["publish_date"] >= datetime.strptime('2021-03-01', '%Y-%m-%d').date()) &
    (willax_sinoph_sub["publish_date"] <= datetime.strptime('2021-09-30', '%Y-%m-%d').date())
]

wil_sino_mar_sep_21.shape'''
# Out:
# (32, 8)

# %%
df_prsd_comments = pd.DataFrame(video_comments_dict['9K9Vpk2N38M'])
df_prsd_comments
# Out:
#          video_id                             commenter_channel_url  \
# 0     9K9Vpk2N38M  http://www.youtube.com/@percyvelasquezernani2873
# 1     9K9Vpk2N38M          http://www.youtube.com/@jhosuacaverli282
# 2     9K9Vpk2N38M        http://www.youtube.com/@mathiasinfante5435
# 3     9K9Vpk2N38M            http://www.youtube.com/@patyruelas8866
# 4     9K9Vpk2N38M  http://www.youtube.com/@juanmitcheloretipula8294
# ...           ...                                               ...
# 1961         None              http://www.youtube.com/@ambarzoe9654
# 1962         None                http://www.youtube.com/@whoism1367
# 1963         None          http://www.youtube.com/@andreamarino1329
# 1964         None            http://www.youtube.com/@josezarate8134
# 1965         None   http://www.youtube.com/@gessicaparvinadelao6381
#
#           commenter_channel_id commenter_channel_display_name  \
# 0     UCiwWo3cSyRx7eyeE-fg-mow      @percyvelasquezernani2873
# ...
